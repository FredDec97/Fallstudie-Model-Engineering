# %%
import pandas as pd

# Daten einlesen
test = pd.read_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/test_data.csv')
train = pd.read_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/train_data.csv')

# Datentypen der Spalten anzeigen
print("Train Data Types:")
print(train.dtypes)

print("\nTest Data Types:")
print(test.dtypes)

# Identifizierung der nicht-numerischen Spalten
non_numerical_train = train.select_dtypes(include=['object', 'datetime']).columns
non_numerical_test = test.select_dtypes(include=['object', 'datetime']).columns

print("\nNicht-numerische Spalten im Trainingsdatensatz:")
print(non_numerical_train)

print("\nNicht-numerische Spalten im Testdatensatz:")
print(non_numerical_test)
# Out:
# Train Data Types:
# date                            object
# Unnamed: 0                       int64
# n_sick                           int64
# calls                            int64
# n_duty                           int64
# n_sby                            int64
# sby_need                         int64
# dafted                           int64
# weekday                          int64
# year                             int64
# calendarweek                     int64
# month                            int64
# quarter                          int64
# season                           int64
# Feiertage                        int64
# schulferien                      int64
# Sick-ratio                     float64
# Residuals_calls                float64
# Residuals_Sick-ratio           float64
# Ausreißer_Sick-ratio              bool
# rolling_mean_7_calls           float64
# rolling_mean_7_Sick-ratio      float64
# lag_49_calls                   float64
# lag_365_calls                  float64
# lag_49_Sickratio               float64
# lag_365_Sickratio              float64
# average7days45lag_calls        float64
# average7days45lag_Sickratio    float64
# dtype: object
#
# Test Data Types:
# date                            object
# Unnamed: 0                       int64
# n_sick                           int64
# calls                            int64
# n_duty                           int64
# n_sby                            int64
# sby_need                         int64
# dafted                           int64
# weekday                          int64
# year                             int64
# calendarweek                     int64
# month                            int64
# quarter                          int64
# season                           int64
# Feiertage                        int64
# schulferien                      int64
# Sick-ratio                     float64
# Residuals_calls                float64
# Residuals_Sick-ratio           float64
# Ausreißer_Sick-ratio              bool
# rolling_mean_7_calls           float64
# rolling_mean_7_Sick-ratio      float64
# lag_49_calls                   float64
# lag_365_calls                  float64
# lag_49_Sickratio               float64
# lag_365_Sickratio              float64
# average7days45lag_calls        float64
# average7days45lag_Sickratio    float64
# dtype: object
#
# Nicht-numerische Spalten im Trainingsdatensatz:
# Index(['date'], dtype='object')
#
# Nicht-numerische Spalten im Testdatensatz:
# Index(['date'], dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error as sklearn_mape

# Daten einlesen
test = pd.read_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/test_data.csv')
train = pd.read_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/train_data.csv')

# Datums-Spalte in Datetime-Format umwandeln
test['date'] = pd.to_datetime(test['date'])
train['date'] = pd.to_datetime(train['date'])

# Features und Zielvariable definieren
# Entferne 'date' aus den Features, falls sie nicht für das Modell verwendet wird
X_train = train.drop(['date', 'weekday', 'schulferien', 'calendarweek', 'month', 'quarter', 'Feiertage', 'season', 'year', 'lag_49_calls', 'lag_365_calls', 'average7days45lag_calls'], axis=1)  # Unabhängige Variablen (Features)
y_train = train['calls']  # Abhängige Variable (Anzahl der Anrufe)

X_test = test.drop(['date', 'weekday', 'schulferien', 'calendarweek', 'month', 'quarter', 'Feiertage', 'season', 'year', 'lag_49_calls', 'lag_365_calls', 'average7days45lag_calls'], axis=1)  # Unabhängige Variablen (Features)
y_test = test['calls']  # Abhängige Variable (Anzahl der Anrufe)

# Fehlende Werte behandeln
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

# Modell erstellen
model = LinearRegression()

# Modell trainieren
model.fit(X_train, y_train)

# Vorhersagen auf dem Testdatensatz treffen
y_pred = model.predict(X_test)

# MAPE berechnen
mape = sklearn_mape(y_test, y_pred)
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')

# Vergleich von Vorhersagen und tatsächlichen Werten
comparison = pd.DataFrame({'Date': test['date'], 'Actual': y_test, 'Predicted': y_pred})
comparison = comparison.sort_values(by='Date')  # Sortieren nach Datum

print(comparison.head())

# Speichern der Vorhersagen in prediction_df
prediction_df = pd.DataFrame({
    'date': test['date'],  # Datum aus dem Testdatensatz
    'MLR': y_pred         # Vorhersagen des Modells
})

# Speichern der DataFrame als CSV-Datei
prediction_df.to_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/prediction_MLR_Calls.csv', index=False)


# Plotten der Ergebnisse
plt.figure(figsize=(12, 6))
plt.plot(comparison['Date'], comparison['Actual'], label='Tatsächliche Werte', marker='o')
plt.plot(comparison['Date'], comparison['Predicted'], label='Vorhergesagte Werte', marker='x')
plt.xlabel('Datum')
plt.ylabel('Anzahl der Anrufe')
plt.title('Tatsächliche vs. Vorhergesagte Werte')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Train Data Types:
# Unnamed: 0                       int64
# n_sick                           int64
# calls                            int64
# n_duty                           int64
# n_sby                            int64
# sby_need                         int64
# dafted                           int64
# Sick-ratio                     float64
# Residuals_calls                float64
# Residuals_Sick-ratio           float64
# Ausreißer_Sick-ratio              bool
# rolling_mean_7_calls           float64
# rolling_mean_7_Sick-ratio      float64
# lag_49_Sickratio               float64
# lag_365_Sickratio              float64
# average7days45lag_Sickratio    float64
# dtype: object
#
# Test Data Types:
# Unnamed: 0                       int64
# n_sick                           int64
# calls                            int64
# n_duty                           int64
# n_sby                            int64
# sby_need                         int64
# dafted                           int64
# Sick-ratio                     float64
# Residuals_calls                float64
# Residuals_Sick-ratio           float64
# Ausreißer_Sick-ratio              bool
# rolling_mean_7_calls           float64
# rolling_mean_7_Sick-ratio      float64
# lag_49_Sickratio               float64
# lag_365_Sickratio              float64
# average7days45lag_Sickratio    float64
# dtype: object
# Mean Absolute Percentage Error (MAPE): 0.00%
#         Date  Actual  Predicted
# 0 2018-05-27    7428     7428.0
# 1 2018-05-28    8862     8862.0
# 2 2018-05-29    8226     8226.0
# 3 2018-05-30    8064     8064.0
# 4 2018-05-31    7392     7392.0
