# %%
import pandas as pd
from datetime import datetime, timedelta

# Pfad zur CSV-Datei
file_path = '/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed_data.csv'

# Daten einlesen
data = pd.read_csv(file_path)

# Überprüfen, ob eine Datums-Spalte existiert
# Angenommen, die Datums-Spalte heißt 'date' und ist im Format 'YYYY-MM-DD'
# Falls der Name anders ist, ändere 'date' entsprechend
if 'date' not in data.columns:
    raise ValueError("Die CSV-Datei muss eine 'date'-Spalte enthalten.")

# Umwandeln der Datums-Spalte in datetime-Format
data['date'] = pd.to_datetime(data['date'])

# Sortieren der Daten nach Datum
data = data.sort_values(by='date')

# Bestimmen des Enddatums für den Testdatensatz (letztes Datum in den Daten)
end_date = data['date'].max()

# Bestimmen des Startdatums für den Testdatensatz (ein Jahr vor dem Enddatum)
start_date = end_date - timedelta(days=365)

# Aufteilen in Test- und Trainingsdaten
test_data = data[(data['date'] >= start_date) & (data['date'] <= end_date)]
train_data = data[data['date'] < start_date]

# Überprüfen der Daten
print("Trainingsdatensatz:")
print(train_data.head())
print("\nTestdatensatz:")
print(test_data.head())

# Optional: Speichern der Trainings- und Testdaten in separate CSV-Dateien
train_data.to_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/train_data.csv', index=False)
test_data.to_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/test_data.csv', index=False)
# Out:
# Trainingsdatensatz:
#         date  Unnamed: 0  n_sick  calls  n_duty  n_sby  sby_need  dafted  \
# 0 2016-04-01           0      73   8154    1700     90      8154    8154
# 1 2016-04-02           1      64   8526    1700     90      8526    8526
# 2 2016-04-03           2      68   8088    1700     90      8088    8088
# 3 2016-04-04           3      71   7044    1700     90      7044    7044
# 4 2016-04-05           4      63   7236    1700     90      7236    7236
#
#     weekday  calendarweek  month  quarter    season  schulferien  Sick-ratio  \
# 0    Friday            13  April        2  Frühling         True    0.042941
# 1  Saturday            13  April        2  Frühling         True    0.037647
# 2    Sunday            13  April        2  Frühling        False    0.040000
# 3    Monday            14  April        2  Frühling        False    0.041765
# 4   Tuesday            14  April        2  Frühling        False    0.037059
#
#    Residuals_calls  Residuals_Sick-ratio  Ausreißer_Sick-ratio  \
# 0              NaN                   NaN                 False
# 1              NaN                   NaN                 False
# 2              NaN                   NaN                 False
# 3      -660.846232                   NaN                 False
# 4      -378.543096                   NaN                 False
#
#    Ausreißer_Calls
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
#
# Testdatensatz:
#           date  Unnamed: 0  n_sick  calls  n_duty  n_sby  sby_need  dafted  \
# 786 2018-05-27         786      88   7428    1900     90      7428    7428
# 787 2018-05-28         787      80   8862    1900     90      8862    8862
# 788 2018-05-29         788      70   8226    1900     90      8226    8226
# 789 2018-05-30         789      68   8064    1900     90      8064    8064
# 790 2018-05-31         790      67   7392    1900     90      7392    7392
#
#        weekday  calendarweek month  quarter    season  schulferien  \
# 786     Sunday            21   May        2  Frühling        False
# 787     Monday            22   May        2  Frühling        False
# 788    Tuesday            22   May        2  Frühling        False
# 789  Wednesday            22   May        2  Frühling        False
# 790   Thursday            22   May        2  Frühling        False
#
#      Sick-ratio  Residuals_calls  Residuals_Sick-ratio  Ausreißer_Sick-ratio  \
# 786    0.046316       -92.120435              0.006618                 False
# 787    0.042105       594.868054              0.002557                 False
# 788    0.036842      -482.257382              0.000202                 False
# 789    0.035789      -635.900239              0.000231                 False
# 790    0.035263     -1519.917660              0.000803                 False
#
#      Ausreißer_Calls
# 786            False
# 787            False
# 788            False
# 789            False
# 790            False
