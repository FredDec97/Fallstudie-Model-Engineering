# %%
import pandas as pd
from datetime import datetime, timedelta

# Pfad zur CSV-Datei
file_path = '/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/processed_data.csv'

# Daten einlesen
data = pd.read_csv(file_path) 

print(data)

# Überprüfen, ob eine Datums-Spalte existiert
# Angenommen, die Datums-Spalte heißt 'date' und ist im Format 'YYYY-MM-DD'
# Falls der Name anders ist, ändere 'date' entsprechend
if 'date' not in data.columns:
    raise ValueError("Die CSV-Datei muss eine 'date'-Spalte enthalten.")

# Umwandeln der Datums-Spalte in datetime-Format
data['date'] = pd.to_datetime(data['date'])

# Sortieren der Daten nach Datum
data = data.sort_values(by='date')

# Bestimmen des Enddatums für den Testdatensatz (letztes Datum in den Daten)
end_date = data['date'].max()

# Bestimmen des Startdatums für den Testdatensatz (ein Jahr vor dem Enddatum)
start_date = end_date - timedelta(days=365)

# Aufteilen in Test- und Trainingsdaten
test_data = data[(data['date'] >= start_date) & (data['date'] <= end_date)]
train_data = data[data['date'] < start_date]

# Überprüfen der Daten
print("Trainingsdatensatz:")
print(train_data.head())
print("\nTestdatensatz:")
print(test_data.head())
print(data.head())

# Optional: Speichern der Trainings- und Testdaten in separate CSV-Dateien
train_data.to_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/train_data.csv', index=False)
test_data.to_csv('/Users/frederic/Desktop/Fallstudie-Model-Engineering/data/processed/test_data.csv', index=False)
# Out:
#             date  Unnamed: 0  n_sick  calls  n_duty  n_sby  sby_need  dafted  \
# 0     2016-04-01           0      73   8154    1700     90         4       0
# 1     2016-04-02           1      64   8526    1700     90        70       0
# 2     2016-04-03           2      68   8088    1700     90         0       0
# 3     2016-04-04           3      71   7044    1700     90         0       0
# 4     2016-04-05           4      63   7236    1700     90         0       0
# ...          ...         ...     ...    ...     ...    ...       ...     ...
# 1147  2019-05-23        1147      86   8544    1900     90         0       0
# 1148  2019-05-24        1148      81   8814    1900     90         0       0
# 1149  2019-05-25        1149      76   9846    1900     90       146      56
# 1150  2019-05-26        1150      83   9882    1900     90       160      70
# 1151  2019-05-27        1151      77   8790    1900     90         0       0
#
#       weekday  year  ...  Residuals_Sick-ratio  Ausreißer_Sick-ratio  \
# 0           4  2016  ...              0.006245                 False
# 1           5  2016  ...              0.006245                 False
# 2           6  2016  ...              0.006245                 False
# 3           0  2016  ...              0.006245                 False
# 4           1  2016  ...              0.006245                 False
# ...       ...   ...  ...                   ...                   ...
# 1147        3  2019  ...                   NaN                 False
# 1148        4  2019  ...                   NaN                 False
# 1149        5  2019  ...                   NaN                 False
# 1150        6  2019  ...                   NaN                 False
# 1151        0  2019  ...                   NaN                 False
#
#       rolling_mean_7_calls  rolling_mean_7_Sick-ratio  lag_49_calls  \
# 0              7392.000000                   0.039748        8154.0
# 1              7392.000000                   0.039748        8154.0
#           date  Unnamed: 0  n_sick  calls  n_duty  n_sby  sby_need  dafted  \
# 786 2018-05-27         786      88   7428    1900     90         0       0
# 787 2018-05-28         787      80   8862    1900     90         0       0
# 788 2018-05-29         788      70   8226    1900     90         0       0
# 789 2018-05-30         789      68   8064    1900     90         0       0
# 790 2018-05-31         790      67   7392    1900     90         0       0
#
#      weekday  year  ...  Residuals_Sick-ratio  Ausreißer_Sick-ratio  \
# 786        6  2018  ...              0.006618                 False
# 787        0  2018  ...              0.002557                 False
# 788        1  2018  ...              0.000202                 False
# 789        2  2018  ...              0.000231                 False
# 790        3  2018  ...              0.000803                 False
#
#      rolling_mean_7_calls  rolling_mean_7_Sick-ratio  lag_49_calls  \
# 786           8209.714286                   0.045865        8268.0
# 787           8096.571429                   0.046015        9438.0
# 788           8065.714286                   0.045038        8580.0
# 789           8157.428571                   0.044135        7686.0
# 790           7954.285714                   0.042406       10080.0
#
#      lag_365_calls  lag_49_Sickratio  lag_365_Sickratio  \
# 786         7290.0          0.036842           0.028333
# 787         8538.0          0.038947           0.032222
# 788         8112.0          0.034737           0.031667
# 789         7098.0          0.036842           0.030556
# 790         9294.0          0.038421           0.028889
#
#      average7days45lag_calls  average7days45lag_Sickratio
# 786              8844.000000                     0.036692
# 787              8672.571429                     0.037068
# 788              8713.714286                     0.036767
# 789              8644.285714                     0.036391
# 790              8461.714286                     0.035338
#
# [5 rows x 28 columns]
#         date  Unnamed: 0  n_sick  calls  n_duty  n_sby  sby_need  dafted  \
# 0 2016-04-01           0      73   8154    1700     90         4       0
# 1 2016-04-02           1      64   8526    1700     90        70       0
# 2 2016-04-03           2      68   8088    1700     90         0       0
# 3 2016-04-04           3      71   7044    1700     90         0       0
# 4 2016-04-05           4      63   7236    1700     90         0       0
#
#    weekday  year  ...  Residuals_Sick-ratio  Ausreißer_Sick-ratio  \
# 0        4  2016  ...              0.006245                 False
# 1        5  2016  ...              0.006245                 False
# 2        6  2016  ...              0.006245                 False
# 3        0  2016  ...              0.006245                 False
# 4        1  2016  ...              0.006245                 False
#
#    rolling_mean_7_calls  rolling_mean_7_Sick-ratio  lag_49_calls  \
# 0                7392.0                   0.039748        8154.0
# 1                7392.0                   0.039748        8154.0
# 2                7392.0                   0.039748        8154.0
# 3                7392.0                   0.039748        8154.0
# 4                7392.0                   0.039748        8154.0
#
#    lag_365_calls  lag_49_Sickratio  lag_365_Sickratio  \
# 0         8154.0          0.042941           0.042941
# 1         8154.0          0.042941           0.042941
# 2         8154.0          0.042941           0.042941
# 3         8154.0          0.042941           0.042941
# 4         8154.0          0.042941           0.042941
#
#    average7days45lag_calls  average7days45lag_Sickratio
# 0                   7392.0                     0.039748
# 1                   7392.0                     0.039748
# 2                   7392.0                     0.039748
# 3                   7392.0                     0.039748
# 4                   7392.0                     0.039748
#
# [5 rows x 28 columns]
